# %% [markdown]
# ## API wrappers: Create a spotify playlist with songs

# %%
#importing libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
string
# Out:
# 'clientid:aac13d68b273498286befa6f4345b6fc\nclientsecret:1253ee99eff541a28df99bce0d83a0a6'

# %%
string.split('\n')
# Out:
# ['clientid:aac13d68b273498286befa6f4345b6fc',
#  'clientsecret:1253ee99eff541a28df99bce0d83a0a6']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        print(line.split(':')) #hash this line later
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()
# Out:
# ['clientid', 'aac13d68b273498286befa6f4345b6fc']
# ['clientsecret', '1253ee99eff541a28df99bce0d83a0a6']

# %%
secrets_dict # hash this line later
# Out:
# {'clientid': 'aac13d68b273498286befa6f4345b6fc',
#  'clientsecret': '1253ee99eff541a28df99bce0d83a0a6'}

# %%
# authentication with secrets

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %% [markdown]
# #### Collecting Database of songs from Spotify Playlist

# %%
# playlist1 - 'https://open.spotify.com/playlist/6FKDzNYZ8IW1pvYVF4zUN2'
# Playlist2 - 'https://open.spotify.com/playlist/5S8SJdl1BDc0ugpkEvFsIL'
# playlist3 - 'https://open.spotify.com/playlist/6yPiKpy7evrwvZodByKvM9'
# playlist4 - 'https://open.spotify.com/playlist/1QfbJBydxHUJuQ0DeNNZTm'
# playlist5 - 'https://open.spotify.com/playlist/5xqpyfZyS1DVysoevdVyEn'

# %%
playlist1 = sp.user_playlist_tracks("spotify", "6FKDzNYZ8IW1pvYVF4zUN2")

# %%
#playlist1

# %%
# Let's look at items and total:
playlist1.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist1["items"][0]["track"]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#     'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#     'id': '0TnOYISbd1XYRBk9myaseg',
#     'name': 'Pitbull',
#     'type': 'artist',
#     'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#   'available_markets': ['AR',
#    'BO',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'DO',
#    'EC',
#    'SV',
#    'GT',
#    'HN',
#    'HK',
#    'IE',
#    'MY',
#    'MX',
#    'NI',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'SG',
#    'TW',
#    'UY',
#    'US',
#    'GB',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'FM',
#    'NA',
#    'NE',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TT',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7sIlk4PsSWt7WhUs0JsFoG'},
#   'href': 'https://api.spotify.com/v1/albums/7sIlk4PsSWt7WhUs0JsFoG',
#   'id': '7sIlk4PsSWt7WhUs0JsFoG',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735c3714e2591b30f2f5194704',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025c3714e2591b30f2f5194704',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515c3714e2591b30f2f5194704',
#     'width': 64}],
#   'name': 'Global Warming: Meltdown (Deluxe Version)',
#   'release_date': '2012',
#   'release_date_precision': 'year',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:7sIlk4PsSWt7WhUs0JsFoG'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#    'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#    'id': '0TnOYISbd1XYRBk9myaseg',
#    'name': 'Pitbull',
#    'type': 'artist',
#    'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LqNN22kT3074XbTVUrhzX'},
#    'href': 'https://api.spotify.com/v1/artists/6LqNN22kT3074XbTVUrhzX',
#    'id': '6LqNN22kT3074XbTVUrhzX',
#    'name': 'Kesha',
#    'type': 'artist',
#    'uri': 'spotify:artist:6LqNN22kT3074XbTVUrhzX'}],
#  'available_markets': ['AR',
#   'BO',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'DO',
#   'EC',
#   'SV',
#   'GT',
#   'HN',
#   'HK',
#   'IE',
#   'MY',
#   'MX',
#   'NI',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'SG',
#   'TW',
#   'UY',
#   'US',
#   'GB',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'FM',
#   'NA',
#   'NE',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TT',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET'],
#  'disc_number': 1,
#  'duration_ms': 204200,
#  'episode': False,
#  'explicit': False,
#  'external_ids': {'isrc': 'USRC11301695'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/3tgZ9vmhuAY9wEoNUJskzV'},
#  'href': 'https://api.spotify.com/v1/tracks/3tgZ9vmhuAY9wEoNUJskzV',
#  'id': '3tgZ9vmhuAY9wEoNUJskzV',
#  'is_local': False,
#  'name': 'Timber (feat. Ke$ha)',
#  'popularity': 65,
#  'preview_url': 'https://p.scdn.co/mp3-preview/54825c719d56bd5b737ac7c1aa3ce41ad3eef338?cid=aac13d68b273498286befa6f4345b6fc',
#  'track': True,
#  'track_number': 13,
#  'type': 'track',
#  'uri': 'spotify:track:3tgZ9vmhuAY9wEoNUJskzV'}

# %%
playlist1["items"][0]['track']['artists'][0]['name']
# Out:
# 'Pitbull'

# %%
playlist1["items"][0]["track"]["name"]
# Out:
# 'Timber (feat. Ke$ha)'

# %%
# let's see how many songs are in this playlist:
playlist1["total"]
# Out:
# 10000

# %%
playlist1["next"]
# Out:
# 'https://api.spotify.com/v1/playlists/6FKDzNYZ8IW1pvYVF4zUN2/tracks?offset=100&limit=100&additional_types=track'

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
# getting all the somgs from playlist1

all_tracks = get_playlist_tracks("6FKDzNYZ8IW1pvYVF4zUN2")
len(all_tracks)
# Out:
# 10000

# %%
from pandas import json_normalize
tracks1 = json_normalize(all_tracks)

# %%
tracks1.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2017-08-03T23:41:30Z     False          None
# 1  2017-08-03T23:41:19Z     False          None
# 2  2017-08-03T23:43:14Z     False          None
# 3  2017-08-03T23:40:58Z     False          None
# 4  2017-08-03T23:43:10Z     False          None
#
#            added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/exiedous
# 1  https://open.spotify.com/user/exiedous
# 2  https://open.spotify.com/user/exiedous
# 3  https://open.spotify.com/user/exiedous
# 4  https://open.spotify.com/user/exiedous
#
#                                added_by.href added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/exiedous    exiedous          user
# 1  https://api.spotify.com/v1/users/exiedous    exiedous          user
# 2  https://api.spotify.com/v1/users/exiedous    exiedous          user
# 3  https://api.spotify.com/v1/users/exiedous    exiedous          user
# 4  https://api.spotify.com/v1/users/exiedous    exiedous          user
#
#             added_by.uri track.album.album_type  \
# 0  spotify:user:exiedous                  album
# 1  spotify:user:exiedous                  album
# 2  spotify:user:exiedous                  album
# 3  spotify:user:exiedous                  album
# 4  spotify:user:exiedous                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                  track.id track.is_local  \
# 0  3tgZ9vmhuAY9wEoNUJskzV          False
# 1  2EBCVPNAG46nbgs6jXPGvv          False
# 2  6pGUGTIaZ1H4jKHIL4Fged          False
# 3  09TcIuH1ZO7i4vicWKoaN2          False
# 4  1TfqLAPs4K3s2rJMoCokcS          False
#
#                                      track.name track.popularity  \
# 0                          Timber (feat. Ke$ha)               65
# 1                                     Starships               80
# 2                             Wild Strawberries                0
# 3                                     Papaoutai                0
# 4  Sweet Dreams (Are Made of This) - Remastered               85
#
#                                    track.preview_url track.track  \
# 0  https://p.scdn.co/mp3-preview/54825c719d56bd5b...        True
# 1                                               None        True
# 2                                               None        True
# 3                                               None        True
# 4  https://p.scdn.co/mp3-preview/d69101dbd6629547...        True
#
#   track.track_number track.type                             track.uri  \
# 0                 13      track  spotify:track:3tgZ9vmhuAY9wEoNUJskzV
# 1                 10      track  spotify:track:2EBCVPNAG46nbgs6jXPGvv
# 2                  2      track  spotify:track:6pGUGTIaZ1H4jKHIL4Fged
# 3                  2      track  spotify:track:09TcIuH1ZO7i4vicWKoaN2
# 4                  6      track  spotify:track:1TfqLAPs4K3s2rJMoCokcS
#
#   video_thumbnail.url
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 40 columns]

# %%
# we can even create a new column containing these DataFrames! KEEP song URI
# NOTE: need to change this function, since the columns names are now a bit different
def expand_list_dict2(row):
    df = json_normalize(row['track.album.artists'])
    df['song_id'] = row['track.id']
    return df

tracks1['artists_dfs'] = tracks1.apply(expand_list_dict2, axis=1)
tracks1['artists_dfs'][3]
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/5j4HeCoUlzh...  5j4HeCoUlzhfWtjAfM1acR
#
#       name    type                                    uri  \
# 0  Stromae  artist  spotify:artist:5j4HeCoUlzhfWtjAfM1acR
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/5j4HeCoUlzhfWt...  09TcIuH1ZO7i4vicWKoaN2

# %%
# now we create a new dataframe with all these artists
artist_df2 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])
for mini_df in tracks1['artists_dfs']:
    #display(val)
    artist_df2 = pd.concat([artist_df2, mini_df], axis=0)
    
artist_df2
# Out:
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/0TnOYISbd1X...  0TnOYISbd1XYRBk9myaseg
# 0   https://api.spotify.com/v1/artists/0hCNtLu0Jeh...  0hCNtLu0JehylgoiP8L4Gh
# 0   https://api.spotify.com/v1/artists/6n28c9qs9hN...  6n28c9qs9hNGriNa72b26u
# 0   https://api.spotify.com/v1/artists/5j4HeCoUlzh...  5j4HeCoUlzhfWtjAfM1acR
# 0   https://api.spotify.com/v1/artists/0NKDgy9j66h...  0NKDgy9j66h3DLnN8qu1bB
# ..                                                ...                     ...
# 0   https://api.spotify.com/v1/artists/2rekrvrzMex...  2rekrvrzMex0PPBX6zvvfj
# 1   https://api.spotify.com/v1/artists/5PDWYfx3o05...  5PDWYfx3o05zDhOvruFS6N
# 0   https://api.spotify.com/v1/artists/1z4g3DjTBBZ...  1z4g3DjTBBZKhvAroFlhOM
# 0   https://api.spotify.com/v1/artists/1Cs0zKBU1kc...  1Cs0zKBU1kc0i8ypK3B9ai
# 0   https://api.spotify.com/v1/artists/11aa081aKYU...  11aa081aKYUzmeFm0yHdT2
#
#             name    type                                    uri  \
# 0        Pitbull  artist  spotify:artist:0TnOYISbd1XYRBk9myaseg
# 0    Nicki Minaj  artist  spotify:artist:0hCNtLu0JehylgoiP8L4Gh
# 0           PNAU  artist  spotify:artist:6n28c9qs9hNGriNa72b26u
# 0        Stromae  artist  spotify:artist:5j4HeCoUlzhfWtjAfM1acR
# 0     Eurythmics  artist  spotify:artist:0NKDgy9j66h3DLnN8qu1bB
# ..           ...     ...                                    ...
# 0       Quadrant  artist  spotify:artist:2rekrvrzMex0PPBX6zvvfj
# 1           Iris  artist  spotify:artist:5PDWYfx3o05zDhOvruFS6N
# 0     Red Velvet  artist  spotify:artist:1z4g3DjTBBZKhvAroFlhOM
# 0   David Guetta  artist  spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai
# 0           S3RL  artist  spotify:artist:11aa081aKYUzmeFm0yHdT2
#
#                                 external_urls.spotify                 song_id
# 0   https://open.spotify.com/artist/0TnOYISbd1XYRB...  3tgZ9vmhuAY9wEoNUJskzV
# 0   https://open.spotify.com/artist/0hCNtLu0Jehylg...  2EBCVPNAG46nbgs6jXPGvv
# 0   https://open.spotify.com/artist/6n28c9qs9hNGri...  6pGUGTIaZ1H4jKHIL4Fged
# 0   https://open.spotify.com/artist/5j4HeCoUlzhfWt...  09TcIuH1ZO7i4vicWKoaN2
# 0   https://open.spotify.com/artist/0NKDgy9j66h3DL...  1TfqLAPs4K3s2rJMoCokcS
# ..                                                ...                     ...
# 0   https://open.spotify.com/artist/2rekrvrzMex0PP...  28d1X9lfagOD4iFULH4qEK
# 1   https://open.spotify.com/artist/5PDWYfx3o05zDh...  28d1X9lfagOD4iFULH4qEK
# 0   https://open.spotify.com/artist/1z4g3DjTBBZKhv...  5HiSc2ZCGn8L3cH3qSwzBT
# 0   https://open.spotify.com/artist/1Cs0zKBU1kc0i8...  2rgtCOVK2tpfao2VjURn84
# 0   https://open.spotify.com/artist/11aa081aKYUzme...  6XQhcuKiotvDsk8rBlrySQ
#
# [10772 rows x 7 columns]

# %%
# now we merge (join) the two dataframes, keeping only the fields we need
df_merged2 = pd.merge(left=tracks1,
                    right=artist_df2,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged2.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2017-08-03T23:41:30Z     False          None
# 1  2017-08-03T23:41:19Z     False          None
# 2  2017-08-03T23:43:14Z     False          None
# 3  2017-08-03T23:40:58Z     False          None
# 4  2017-08-03T23:43:10Z     False          None
#
#            added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/exiedous
# 1  https://open.spotify.com/user/exiedous
# 2  https://open.spotify.com/user/exiedous
# 3  https://open.spotify.com/user/exiedous
# 4  https://open.spotify.com/user/exiedous
#
#                                added_by.href added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/exiedous    exiedous          user
# 1  https://api.spotify.com/v1/users/exiedous    exiedous          user
# 2  https://api.spotify.com/v1/users/exiedous    exiedous          user
# 3  https://api.spotify.com/v1/users/exiedous    exiedous          user
# 4  https://api.spotify.com/v1/users/exiedous    exiedous          user
#
#             added_by.uri track.album.album_type  \
# 0  spotify:user:exiedous                  album
# 1  spotify:user:exiedous                  album
# 2  spotify:user:exiedous                  album
# 3  spotify:user:exiedous                  album
# 4  spotify:user:exiedous                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                               track.uri video_thumbnail.url  \
# 0  spotify:track:3tgZ9vmhuAY9wEoNUJskzV                None
# 1  spotify:track:2EBCVPNAG46nbgs6jXPGvv                None
# 2  spotify:track:6pGUGTIaZ1H4jKHIL4Fged                None
# 3  spotify:track:09TcIuH1ZO7i4vicWKoaN2                None
# 4  spotify:track:1TfqLAPs4K3s2rJMoCokcS                None
#
#                                          artists_dfs  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/0TnOYISbd1X...  0TnOYISbd1XYRBk9myaseg
# 1  https://api.spotify.com/v1/artists/0hCNtLu0Jeh...  0hCNtLu0JehylgoiP8L4Gh
# 2  https://api.spotify.com/v1/artists/6n28c9qs9hN...  6n28c9qs9hNGriNa72b26u
# 3  https://api.spotify.com/v1/artists/5j4HeCoUlzh...  5j4HeCoUlzhfWtjAfM1acR
# 4  https://api.spotify.com/v1/artists/0NKDgy9j66h...  0NKDgy9j66h3DLnN8qu1bB
#
#           name    type                                    uri  \
# 0      Pitbull  artist  spotify:artist:0TnOYISbd1XYRBk9myaseg
# 1  Nicki Minaj  artist  spotify:artist:0hCNtLu0JehylgoiP8L4Gh
# 2         PNAU  artist  spotify:artist:6n28c9qs9hNGriNa72b26u
# 3      Stromae  artist  spotify:artist:5j4HeCoUlzhfWtjAfM1acR
# 4   Eurythmics  artist  spotify:artist:0NKDgy9j66h3DLnN8qu1bB
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/0TnOYISbd1XYRB...  3tgZ9vmhuAY9wEoNUJskzV
# 1  https://open.spotify.com/artist/0hCNtLu0Jehylg...  2EBCVPNAG46nbgs6jXPGvv
# 2  https://open.spotify.com/artist/6n28c9qs9hNGri...  6pGUGTIaZ1H4jKHIL4Fged
# 3  https://open.spotify.com/artist/5j4HeCoUlzhfWt...  09TcIuH1ZO7i4vicWKoaN2
# 4  https://open.spotify.com/artist/0NKDgy9j66h3DL...  1TfqLAPs4K3s2rJMoCokcS
#
# [5 rows x 48 columns]

# %%
playlist1_final = df_merged2[['track.name', 'name', 'song_id']]
playlist1_final
# Out:
#                                          track.name          name  \
# 0                              Timber (feat. Ke$ha)       Pitbull
# 1                                         Starships   Nicki Minaj
# 2                                 Wild Strawberries          PNAU
# 3                                         Papaoutai       Stromae
# 4      Sweet Dreams (Are Made of This) - Remastered    Eurythmics
# ...                                             ...           ...
# 10971            Dark Star - Homemade Weapons Remix      Quadrant
# 10972            Dark Star - Homemade Weapons Remix          Iris
# 10973                       러시안 룰렛 Russian Roulette    Red Velvet
# 10974          Lovers on the Sun (feat. Sam Martin)  David Guetta
# 10975                      Bass Slut - X-FIR3 Remix          S3RL
#
#                       song_id
# 0      3tgZ9vmhuAY9wEoNUJskzV
# 1      2EBCVPNAG46nbgs6jXPGvv
# 2      6pGUGTIaZ1H4jKHIL4Fged
# 3      09TcIuH1ZO7i4vicWKoaN2
# 4      1TfqLAPs4K3s2rJMoCokcS
# ...                       ...
# 10971  28d1X9lfagOD4iFULH4qEK
# 10972  28d1X9lfagOD4iFULH4qEK
# 10973  5HiSc2ZCGn8L3cH3qSwzBT
# 10974  2rgtCOVK2tpfao2VjURn84
# 10975  6XQhcuKiotvDsk8rBlrySQ
#
# [10976 rows x 3 columns]

# %%
playlist1_final.isna().sum()
# Out:
# track.name    0
# name          0
# song_id       0
# dtype: int64

# %%
#df_merged2.isna().sum()

# %% [markdown]
# #### Audio features

# %%
# get the audio features for a song
sp.audio_features('3tgZ9vmhuAY9wEoNUJskzV')
# Out:
# [{'danceability': 0.589,
#   'energy': 0.966,
#   'key': 11,
#   'loudness': -4.106,
#   'mode': 1,
#   'speechiness': 0.0972,
#   'acousticness': 0.03,
#   'instrumentalness': 0,
#   'liveness': 0.147,
#   'valence': 0.802,
#   'tempo': 129.983,
#   'type': 'audio_features',
#   'id': '3tgZ9vmhuAY9wEoNUJskzV',
#   'uri': 'spotify:track:3tgZ9vmhuAY9wEoNUJskzV',
#   'track_href': 'https://api.spotify.com/v1/tracks/3tgZ9vmhuAY9wEoNUJskzV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tgZ9vmhuAY9wEoNUJskzV',
#   'duration_ms': 204200,
#   'time_signature': 4}]

# %%
chunks = [(i, i+100) for i in range(0, len(playlist1_final), 100)]
chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = playlist1_final['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 10976

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True)

# %%
df_w_audio_ft = pd.merge(left=playlist1_final,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft
# Out:
#                                          track.name          name  \
# 0                              Timber (feat. Ke$ha)       Pitbull
# 1                                         Starships   Nicki Minaj
# 2                                 Wild Strawberries          PNAU
# 3                                         Papaoutai       Stromae
# 4      Sweet Dreams (Are Made of This) - Remastered    Eurythmics
# ...                                             ...           ...
# 10971            Dark Star - Homemade Weapons Remix      Quadrant
# 10972            Dark Star - Homemade Weapons Remix          Iris
# 10973                       러시안 룰렛 Russian Roulette    Red Velvet
# 10974          Lovers on the Sun (feat. Sam Martin)  David Guetta
# 10975                      Bass Slut - X-FIR3 Remix          S3RL
#
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      3tgZ9vmhuAY9wEoNUJskzV         0.589   0.966   11    -4.106     1
# 1      2EBCVPNAG46nbgs6jXPGvv         0.747   0.716   11    -2.457     0
# 2      6pGUGTIaZ1H4jKHIL4Fged         0.647   0.933    7    -4.056     1
# 3      09TcIuH1ZO7i4vicWKoaN2         0.733   0.818   10    -7.222     0
# 4      1TfqLAPs4K3s2rJMoCokcS         0.692   0.711    0    -7.498     0
# ...                       ...           ...     ...  ...       ...   ...
# 10971  28d1X9lfagOD4iFULH4qEK         0.337   0.977    9    -1.995     1
# 10972  28d1X9lfagOD4iFULH4qEK         0.337   0.977    9    -1.995     1
# 10973  5HiSc2ZCGn8L3cH3qSwzBT         0.726   0.903    7    -2.277     0
# 10974  2rgtCOVK2tpfao2VjURn84         0.645   0.891    6    -2.505     0
# 10975  6XQhcuKiotvDsk8rBlrySQ         0.330   0.970   10    -7.316     0
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.0972      0.030000  ...    0.1470   0.8020  129.983
# 1           0.0750      0.135000  ...    0.2510   0.7510  125.008
# 2           0.1110      0.000351  ...    0.3340   0.3320  119.921
# 3           0.0859      0.024100  ...    0.0636   0.2530  116.019
# 4           0.0317      0.225000  ...    0.1200   0.8750  125.135
# ...            ...           ...  ...       ...      ...      ...
# 10971       0.0976      0.004920  ...    0.2600   0.0582  169.867
# 10972       0.0976      0.004920  ...    0.2600   0.0582  169.867
# 10973       0.0357      0.055000  ...    0.1580   0.9580  129.986
# 10974       0.0387      0.093200  ...    0.3790   0.5680  124.915
# 10975       0.1010      0.000320  ...    0.5460   0.3090  175.142
#
#                  type                      id  \
# 0      audio_features  3tgZ9vmhuAY9wEoNUJskzV
# 1      audio_features  2EBCVPNAG46nbgs6jXPGvv
# 2      audio_features  6pGUGTIaZ1H4jKHIL4Fged
# 3      audio_features  09TcIuH1ZO7i4vicWKoaN2
# 4      audio_features  1TfqLAPs4K3s2rJMoCokcS
# ...               ...                     ...
# 10971  audio_features  28d1X9lfagOD4iFULH4qEK
# 10972  audio_features  28d1X9lfagOD4iFULH4qEK
# 10973  audio_features  5HiSc2ZCGn8L3cH3qSwzBT
# 10974  audio_features  2rgtCOVK2tpfao2VjURn84
# 10975  audio_features  6XQhcuKiotvDsk8rBlrySQ
#
#                                         uri  \
# 0      spotify:track:3tgZ9vmhuAY9wEoNUJskzV
# 1      spotify:track:2EBCVPNAG46nbgs6jXPGvv
# 2      spotify:track:6pGUGTIaZ1H4jKHIL4Fged
# 3      spotify:track:09TcIuH1ZO7i4vicWKoaN2
# 4      spotify:track:1TfqLAPs4K3s2rJMoCokcS
# ...                                     ...
# 10971  spotify:track:28d1X9lfagOD4iFULH4qEK
# 10972  spotify:track:28d1X9lfagOD4iFULH4qEK
# 10973  spotify:track:5HiSc2ZCGn8L3cH3qSwzBT
# 10974  spotify:track:2rgtCOVK2tpfao2VjURn84
# 10975  spotify:track:6XQhcuKiotvDsk8rBlrySQ
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3tgZ9vmhuAY9...
# 1      https://api.spotify.com/v1/tracks/2EBCVPNAG46n...
# 2      https://api.spotify.com/v1/tracks/6pGUGTIaZ1H4...
# 3      https://api.spotify.com/v1/tracks/09TcIuH1ZO7i...
# 4      https://api.spotify.com/v1/tracks/1TfqLAPs4K3s...
# ...                                                  ...
# 10971  https://api.spotify.com/v1/tracks/28d1X9lfagOD...
# 10972  https://api.spotify.com/v1/tracks/28d1X9lfagOD...
# 10973  https://api.spotify.com/v1/tracks/5HiSc2ZCGn8L...
# 10974  https://api.spotify.com/v1/tracks/2rgtCOVK2tpf...
# 10975  https://api.spotify.com/v1/tracks/6XQhcuKiotvD...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3tgZ...      204200
# 1      https://api.spotify.com/v1/audio-analysis/2EBC...      210627
# 2      https://api.spotify.com/v1/audio-analysis/6pGU...      235107
# 3      https://api.spotify.com/v1/audio-analysis/09Tc...      232147
# 4      https://api.spotify.com/v1/audio-analysis/1Tfq...      216933
# ...                                                  ...         ...
# 10971  https://api.spotify.com/v1/audio-analysis/28d1...      345706
# 10972  https://api.spotify.com/v1/audio-analysis/28d1...      345706
# 10973  https://api.spotify.com/v1/audio-analysis/5HiS...      211244
# 10974  https://api.spotify.com/v1/audio-analysis/2rgt...      203520
# 10975  https://api.spotify.com/v1/audio-analysis/6XQh...      260571
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 10971               4
# 10972               4
# 10973               4
# 10974               4
# 10975               4
#
# [10976 rows x 21 columns]

# %%
cols = df_w_audio_ft.columns
cols
# Out:
# Index(['track.name', 'name', 'song_id', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df_w_audio_ft.isna().sum()
# Out:
# track.name          0
# name                0
# song_id             0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
df_w_audio_ft = df_w_audio_ft.rename(columns={'track.name': 'track_name', 'name': 'artist_name'})

# %%
df_w_audio_ft
# Out:
#                                          track_name   artist_name  \
# 0                              Timber (feat. Ke$ha)       Pitbull
# 1                                         Starships   Nicki Minaj
# 2                                 Wild Strawberries          PNAU
# 3                                         Papaoutai       Stromae
# 4      Sweet Dreams (Are Made of This) - Remastered    Eurythmics
# ...                                             ...           ...
# 10971            Dark Star - Homemade Weapons Remix      Quadrant
# 10972            Dark Star - Homemade Weapons Remix          Iris
# 10973                       러시안 룰렛 Russian Roulette    Red Velvet
# 10974          Lovers on the Sun (feat. Sam Martin)  David Guetta
# 10975                      Bass Slut - X-FIR3 Remix          S3RL
#
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      3tgZ9vmhuAY9wEoNUJskzV         0.589   0.966   11    -4.106     1
# 1      2EBCVPNAG46nbgs6jXPGvv         0.747   0.716   11    -2.457     0
# 2      6pGUGTIaZ1H4jKHIL4Fged         0.647   0.933    7    -4.056     1
# 3      09TcIuH1ZO7i4vicWKoaN2         0.733   0.818   10    -7.222     0
# 4      1TfqLAPs4K3s2rJMoCokcS         0.692   0.711    0    -7.498     0
# ...                       ...           ...     ...  ...       ...   ...
# 10971  28d1X9lfagOD4iFULH4qEK         0.337   0.977    9    -1.995     1
# 10972  28d1X9lfagOD4iFULH4qEK         0.337   0.977    9    -1.995     1
# 10973  5HiSc2ZCGn8L3cH3qSwzBT         0.726   0.903    7    -2.277     0
# 10974  2rgtCOVK2tpfao2VjURn84         0.645   0.891    6    -2.505     0
# 10975  6XQhcuKiotvDsk8rBlrySQ         0.330   0.970   10    -7.316     0
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.0972      0.030000  ...    0.1470   0.8020  129.983
# 1           0.0750      0.135000  ...    0.2510   0.7510  125.008
# 2           0.1110      0.000351  ...    0.3340   0.3320  119.921
# 3           0.0859      0.024100  ...    0.0636   0.2530  116.019
# 4           0.0317      0.225000  ...    0.1200   0.8750  125.135
# ...            ...           ...  ...       ...      ...      ...
# 10971       0.0976      0.004920  ...    0.2600   0.0582  169.867
# 10972       0.0976      0.004920  ...    0.2600   0.0582  169.867
# 10973       0.0357      0.055000  ...    0.1580   0.9580  129.986
# 10974       0.0387      0.093200  ...    0.3790   0.5680  124.915
# 10975       0.1010      0.000320  ...    0.5460   0.3090  175.142
#
#                  type                      id  \
# 0      audio_features  3tgZ9vmhuAY9wEoNUJskzV
# 1      audio_features  2EBCVPNAG46nbgs6jXPGvv
# 2      audio_features  6pGUGTIaZ1H4jKHIL4Fged
# 3      audio_features  09TcIuH1ZO7i4vicWKoaN2
# 4      audio_features  1TfqLAPs4K3s2rJMoCokcS
# ...               ...                     ...
# 10971  audio_features  28d1X9lfagOD4iFULH4qEK
# 10972  audio_features  28d1X9lfagOD4iFULH4qEK
# 10973  audio_features  5HiSc2ZCGn8L3cH3qSwzBT
# 10974  audio_features  2rgtCOVK2tpfao2VjURn84
# 10975  audio_features  6XQhcuKiotvDsk8rBlrySQ
#
#                                         uri  \
# 0      spotify:track:3tgZ9vmhuAY9wEoNUJskzV
# 1      spotify:track:2EBCVPNAG46nbgs6jXPGvv
# 2      spotify:track:6pGUGTIaZ1H4jKHIL4Fged
# 3      spotify:track:09TcIuH1ZO7i4vicWKoaN2
# 4      spotify:track:1TfqLAPs4K3s2rJMoCokcS
# ...                                     ...
# 10971  spotify:track:28d1X9lfagOD4iFULH4qEK
# 10972  spotify:track:28d1X9lfagOD4iFULH4qEK
# 10973  spotify:track:5HiSc2ZCGn8L3cH3qSwzBT
# 10974  spotify:track:2rgtCOVK2tpfao2VjURn84
# 10975  spotify:track:6XQhcuKiotvDsk8rBlrySQ
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3tgZ9vmhuAY9...
# 1      https://api.spotify.com/v1/tracks/2EBCVPNAG46n...
# 2      https://api.spotify.com/v1/tracks/6pGUGTIaZ1H4...
# 3      https://api.spotify.com/v1/tracks/09TcIuH1ZO7i...
# 4      https://api.spotify.com/v1/tracks/1TfqLAPs4K3s...
# ...                                                  ...
# 10971  https://api.spotify.com/v1/tracks/28d1X9lfagOD...
# 10972  https://api.spotify.com/v1/tracks/28d1X9lfagOD...
# 10973  https://api.spotify.com/v1/tracks/5HiSc2ZCGn8L...
# 10974  https://api.spotify.com/v1/tracks/2rgtCOVK2tpf...
# 10975  https://api.spotify.com/v1/tracks/6XQhcuKiotvD...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3tgZ...      204200
# 1      https://api.spotify.com/v1/audio-analysis/2EBC...      210627
# 2      https://api.spotify.com/v1/audio-analysis/6pGU...      235107
# 3      https://api.spotify.com/v1/audio-analysis/09Tc...      232147
# 4      https://api.spotify.com/v1/audio-analysis/1Tfq...      216933
# ...                                                  ...         ...
# 10971  https://api.spotify.com/v1/audio-analysis/28d1...      345706
# 10972  https://api.spotify.com/v1/audio-analysis/28d1...      345706
# 10973  https://api.spotify.com/v1/audio-analysis/5HiS...      211244
# 10974  https://api.spotify.com/v1/audio-analysis/2rgt...      203520
# 10975  https://api.spotify.com/v1/audio-analysis/6XQh...      260571
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 10971               4
# 10972               4
# 10973               4
# 10974               4
# 10975               4
#
# [10976 rows x 21 columns]

# %%
df_w_audio_ft.to_csv('songlist_w_features.csv', index = False)
